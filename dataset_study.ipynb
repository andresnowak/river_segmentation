# %%
import PIL
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = "dataset"

# %%
files_count = 0

for root, dirs, files in os.walk(path):
    #path = root.split(os.sep)
    for file in files:
        files_count += 1

files_count
# Out:
# 4534

# %%
im = Image.open("dataset/dataset_v1/train/masks/img_0000.png")

# %%
im_2 = np.array(im)
im_2 = np.expand_dims(im_2, axis=-1)
im_2.shape
# Out:
# (288, 384, 1)

# %%
im_2 = np.repeat(im_2[:,:], 3, axis=-1)
im_2.shape
# Out:
# (288, 384, 3)

# %%
plt.imshow(im_2[:,:,2])

# %%
print(np.unique(im_2))
# Out:
# [0 1]

# %%
im = Image.open("dataset/dataset_v1/train/images/img_0000.jpg")

# %%
im_2 = np.array(im)
im_2.shape
# Out:
# (288, 384, 3)

# %%
plt.imshow(im_2)
